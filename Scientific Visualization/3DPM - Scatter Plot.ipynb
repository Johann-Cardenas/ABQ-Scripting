# %% [markdown]
# ## **Low Volume Section**

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "CaseName": [r'$D{\mathbf{IC}}$, 4.2, 0\%', 
                 r'$D{\mathbf{IC}}$, 4.2, 2\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 6\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 6\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 0\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 2\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 0\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 3\%', 
                 r'$S{\mathbf{EV}}$, 9.5, 0\%'],
    "DWBU": [1.00, 1.07, 1.00, 1.13, 0.69, 0.79, 1.10, 1.21, 0.65, 0.76, 0.28],
    "DWTDS": [1.00, 1.08, 0.99, 1.14, 0.68, 0.79, 0.47, 0.51, 0.27, 0.32, 0.11],
    "DWNSS": [1.00, 0.85, 0.99, 0.83, 0.80, 0.68, 0.97, 0.79, 0.70, 0.57, 0.42],
    "DWRUT": [1.00, 1.05, 0.99, 1.09, 0.78, 0.87, 0.81, 0.87, 0.58, 0.63, 0.31]
}

df = pd.DataFrame(data)

# Calculating the relative differences with respect to 1
df['Relative DWBU'] = df['DWBU'] - 1
df['Relative DWTDS'] = df['DWTDS'] - 1
df['Relative DWNSS'] = df['DWNSS'] - 1
df['Relative DWRUT'] = df['DWRUT'] - 1

# Plotting
fig, axs = plt.subplots(4, 1, figsize=(4, 5), dpi=200)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Function to create bar plots
def create_bar_plot(ax, data, title):
    colors = ['blue' if val > 0 else 'red' for val in data]
    
    # Background bars
    bg_bars = ax.bar(df['CaseName'], [1] * len(df), bottom=-1, 
                     color='white', edgecolor=colors, linestyle='-', linewidth=1.5, alpha=0.5)
    
    # Foreground bars
    bars = ax.bar(df['CaseName'], data, color=colors, alpha=0.7, edgecolor='black')
    
    ax.axhline(0, color='black', linewidth=0.8)
    ax.set_ylabel(title)
    ax.set_ylim(-1.0, 1.0)
    ax.set_yticks([-1, -0.5, 0, 0.5, 1.0])
    ax.set_yticklabels([0, 0.5, 1.0, 1.5, 2.0])
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
    
    if ax == axs[3]:
        ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
        ax.set_xticks(range(len(df['CaseName'])))
        ax.set_xticklabels(df['CaseName'], rotation=90, fontsize=8)

create_bar_plot(axs[0], df['Relative DWBU'], '$\Delta$ $DW_{BU}$')
create_bar_plot(axs[1], df['Relative DWTDS'], '$\Delta$ $DW_{TDS}$')
create_bar_plot(axs[2], df['Relative DWNSS'], '$\Delta$ $DW_{NSS}$')
create_bar_plot(axs[3], df['Relative DWRUT'], '$\Delta$ $DW_{RUT}$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Thick Section**

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "CaseName": [r'$D{\mathbf{IC}}$, 4.2, 0\%', 
                 r'$D{\mathbf{IC}}$, 4.2, 2\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 6\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 6\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 0\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 2\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 0\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 3\%', 
                 r'$S{\mathbf{EV}}$, 9.5, 0\%'],
    "DWBU": [1.00, 1.06, 1.01, 1.12, 0.68, 0.76, 1.48, 1.58, 0.83, 0.96, 0.32],
    "DWTDS": [1.00, 1.08, 1.00, 1.15, 0.67, 0.78, 0.66, 0.71, 0.37, 0.43, 0.14],
    "DWNSS": [1.00, 0.66, 0.97, 0.62, 0.79, 0.50, 0.90, 0.55, 0.66, 0.39, 0.40],
    "DWRUT": [1.00, 1.14, 1.07, 1.21, 0.87, 1.00, 0.90, 0.96, 0.69, 0.78, 0.43]
}

df = pd.DataFrame(data)

# Calculating the relative differences with respect to 1
df['Relative DWBU'] = df['DWBU'] - 1
df['Relative DWTDS'] = df['DWTDS'] - 1
df['Relative DWNSS'] = df['DWNSS'] - 1
df['Relative DWRUT'] = df['DWRUT'] - 1

# Plotting
fig, axs = plt.subplots(4, 1, figsize=(4, 5), dpi=200)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Function to create bar plots
def create_bar_plot(ax, data, title):
    colors = ['blue' if val > 0 else 'red' for val in data]
    
    # Background bars
    bg_bars = ax.bar(df['CaseName'], [1] * len(df), bottom=-1, 
                     color='white', edgecolor=colors, linestyle='-', linewidth=1.5, alpha=0.5)
    
    # Foreground bars
    bars = ax.bar(df['CaseName'], data, color=colors, alpha=0.7, edgecolor='black')
    
    ax.axhline(0, color='black', linewidth=0.5)
    ax.set_ylabel(title)
    ax.set_ylim(-1.0, 1.0)
    ax.set_yticks([-1, -0.5, 0, 0.5, 1.0])
    ax.set_yticklabels([0, 0.5, 1.0, 1.5, 2.0])
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
    
    if ax == axs[3]:
        ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
        ax.set_xticks(range(len(df['CaseName'])))
        ax.set_xticklabels(df['CaseName'], rotation=90, fontsize=8)

create_bar_plot(axs[0], df['Relative DWBU'], '$\Delta$ $DW_{BU}$')
create_bar_plot(axs[1], df['Relative DWTDS'], '$\Delta$ $DW_{TDS}$')
create_bar_plot(axs[2], df['Relative DWNSS'], '$\Delta$ $DW_{NSS}$')
create_bar_plot(axs[3], df['Relative DWRUT'], '$\Delta$ $DW_{RUT}$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Full Depth**

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "CaseName": [r'$D{\mathbf{IC}}$, 4.2, 0\%', 
                 r'$D{\mathbf{IC}}$, 4.2, 2\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 6\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 6\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 0\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 2\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 0\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 3\%', 
                 r'$S{\mathbf{EV}}$, 9.5, 0\%'],
    "DWBU": [1.00, 1.06, 1.00, 1.11, 0.66, 0.75, 1.72, 1.88, 0.94, 1.10, 0.35],
    "DWTDS": [1.00, 0.95, 1.00, 1.28, 0.66, 0.82, 0.30, 0.29, 0.17, 0.20, 0.06],
    "DWNSS": [1.00, 0.19, 1.19, 0.13, 0.97, 0.10, 0.70, 0.08, 0.42, 0.05, 0.13],
    "DWRUT": [1.00, 1.24, 0.95, 1.35, 0.85, 1.16, 0.57, 0.59, 0.54, 0.57, 0.49]
}

df = pd.DataFrame(data)

# Calculating the relative differences with respect to 1
df['Relative DWBU'] = df['DWBU'] - 1
df['Relative DWTDS'] = df['DWTDS'] - 1
df['Relative DWNSS'] = df['DWNSS'] - 1
df['Relative DWRUT'] = df['DWRUT'] - 1

# Plotting
fig, axs = plt.subplots(4, 1, figsize=(4, 5), dpi=200)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Function to create bar plots
def create_bar_plot(ax, data, title):
    colors = ['blue' if val > 0 else 'red' for val in data]
    
    # Background bars
    bg_bars = ax.bar(df['CaseName'], [1] * len(df), bottom=-1, 
                     color='white', edgecolor=colors, linestyle='-', linewidth=1.5, alpha=0.5)
    
    # Foreground bars
    bars = ax.bar(df['CaseName'], data, color=colors, alpha=0.7, edgecolor='black')
    
    ax.axhline(0, color='black', linewidth=0.5)
    ax.set_ylabel(title)
    ax.set_ylim(-1.0, 1.0)
    ax.set_yticks([-1, -0.5, 0, 0.5, 1.0])
    ax.set_yticklabels([0, 0.5, 1.0, 1.5, 2.0])
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
    
    if ax == axs[3]:
        ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
        ax.set_xticks(range(len(df['CaseName'])))
        ax.set_xticklabels(df['CaseName'], rotation=90, fontsize=8)

create_bar_plot(axs[0], df['Relative DWBU'], '$\Delta$ $DW_{BU}$')
create_bar_plot(axs[1], df['Relative DWTDS'], '$\Delta$ $DW_{TDS}$')
create_bar_plot(axs[2], df['Relative DWNSS'], '$\Delta$ $DW_{NSS}$')
create_bar_plot(axs[3], df['Relative DWRUT'], '$\Delta$ $DW_{RUT}$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **SMA Overlay**

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "CaseName": [r'$D{\mathbf{IC}}$, 4.2, 0\%', 
                 r'$D{\mathbf{IC}}$, 4.2, 2\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 6\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 6\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 0\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 2\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 0\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 3\%', 
                 r'$S{\mathbf{EV}}$, 9.5, 0\%'],
    "DWBU": [1.00, 1.16, 0.90, 1.22, 0.73, 1.03, 0.79, 1.70, 0.56, 0.90, 0.47],
    "DWTDS": [1.00, 0.89, 1.00, 1.27, 0.65, 0.79, 0.25, 0.24, 0.08, 0.16, 0.01],
    "DWNSS": [1.00, 0.24, 1.08, 0.16, 0.88, 0.13, 0.64, 0.09, 0.54, 0.05, 0.12],
    "DWRUT": [1.00, 1.08, 1.01, 1.05, 0.92, 0.98, 0.84, 0.78, 0.53, 0.66, 0.24]
}

df = pd.DataFrame(data)

# Calculating the relative differences with respect to 1
df['Relative DWBU'] = df['DWBU'] - 1
df['Relative DWTDS'] = df['DWTDS'] - 1
df['Relative DWNSS'] = df['DWNSS'] - 1
df['Relative DWRUT'] = df['DWRUT'] - 1

# Plotting
fig, axs = plt.subplots(4, 1, figsize=(4, 5), dpi=200)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Function to create bar plots
def create_bar_plot(ax, data, title):
    colors = ['blue' if val > 0 else 'red' for val in data]
    
    # Background bars
    bg_bars = ax.bar(df['CaseName'], [1] * len(df), bottom=-1, 
                     color='white', edgecolor=colors, linestyle='-', linewidth=1.5, alpha=0.5)
    
    # Foreground bars
    bars = ax.bar(df['CaseName'], data, color=colors, alpha=0.7, edgecolor='black')
    
    ax.axhline(0, color='black', linewidth=0.5)
    ax.set_ylabel(title)
    ax.set_ylim(-1.0, 1.0)
    ax.set_yticks([-1, -0.5, 0, 0.5, 1.0, 1.5])
    ax.set_yticklabels([0, 0.5, 1.0, 1.5, 2.0, 2.5])
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
    
    if ax == axs[3]:
        ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
        ax.set_xticks(range(len(df['CaseName'])))
        ax.set_xticklabels(df['CaseName'], rotation=90, fontsize=8)

create_bar_plot(axs[0], df['Relative DWBU'], '$\Delta$ $DW_{BU}$')
create_bar_plot(axs[1], df['Relative DWTDS'], '$\Delta$ $DW_{TDS}$')
create_bar_plot(axs[2], df['Relative DWNSS'], '$\Delta$ $DW_{NSS}$')
create_bar_plot(axs[3], df['Relative DWRUT'], '$\Delta$ $DW_{RUT}$')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **CDW**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the provided image
data = {
    "CaseName": [r'$D{\mathbf{IC}}$, 4.2, 0\%', 
                 r'$D{\mathbf{IC}}$, 4.2, 2\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.2, 6\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 0\%', 
                 r'$D{\mathbf{EV}}$, 4.7, 6\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 0\%', 
                 r'$S{\mathbf{IC}}$, 6.0, 2\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 0\%', 
                 r'$S{\mathbf{EV}}$, 7.0, 3\%', 
                 r'$S{\mathbf{EV}}$, 9.5, 0\%'],
    "Low Volume": [1.00, 1.02, 0.99, 1.06, 0.74, 0.79, 0.83, 0.85, 0.55, 0.58, 0.28],
    "Thick": [1.00, 1.01, 1.01, 1.06, 0.75, 0.79, 0.95, 0.94, 0.62, 0.64, 0.31],
    "Full Depth": [1.00, 0.90, 1.02, 1.03, 0.78, 0.76, 0.69, 0.59, 0.46, 0.42, 0.25],
    "SMA": [1.00, 0.86, 1.00, 0.93, 0.81, 0.75, 0.65, 0.65, 0.42, 0.44, 0.19]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(4, 4), dpi=200)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Scatter plot
plt.scatter(df['CaseName'], df['Low Volume'], label='Low Volume', color='b', edgecolors='k', marker='o', linewidths=0.5, s=50)
plt.scatter(df['CaseName'], df['Thick'], label='Typical Thick', color='g', edgecolors='k', marker='^', linewidths=0.5, s=50)
plt.scatter(df['CaseName'], df['Full Depth'], label='Full Depth', color='r', edgecolors='k',marker='s', linewidths=0.5,s=50)
plt.scatter(df['CaseName'], df['SMA'], label='SMA', color='y', edgecolors='k', marker='*', linewidths=0.5, s=50)
plt.axhline(1, color='black', linewidth=0.5)

plt.ylabel('Cumulative Distress Ratio $(CDW)$', fontsize=13)
plt.xticks(rotation=90)
plt.legend(loc='lower left')

plt.grid(color='lightgrey', linestyle='--', linewidth=0.25)


# Show plot
plt.tight_layout()
plt.show()
